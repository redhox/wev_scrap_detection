# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
#url = 'https://www.shutterstock.com/fr/search/personne-avec-casque-de-chantier?mreleased=true&people_number=1&measurement=px&min_width=200&min_height=200&image_type=photo'
#url2='https://www.shutterstock.com/fr/search/personne-avec-casque-de-chantier?image_type=photo&measurement=px&min_height=200&min_width=200&mreleased=true&page=2'

# %%
image_set=[]
for i in range(21,50):
    url='https://www.shutterstock.com/fr/search/personne-avec-casque-de-chantier?image_type=photo&measurement=px&min_height=200&min_width=200&mreleased=true&page=2'
    #url=f'https://www.shutterstock.com/fr/search/personne?measurement=px&min_height=200&min_width=200&mreleased=true&image_type=photo&people_number=1&page={i}'
    # Configure the Selenium webdriver
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run Chrome in headless mode
    driver = webdriver.Chrome(options=options)

    # Load the webpage
    driver.get(url)
    # Get the page source after the dynamic content has been loaded
    html_content = driver.page_source

    # Close the Selenium webdriver
    driver.quit()
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    # Find the image tags and extract the src attribute
    image_tags = soup.find_all('img')
    image_addresses = [img['src'] for img in image_tags]
    for img in image_addresses:
        image_set.append(img)

# %%
# Configure the Selenium webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run Chrome in headless mode

# %%
driver = webdriver.Chrome(options=options)

# Load the webpage
driver.get(url)

# %%
# Get the page source after the dynamic content has been loaded
html_content = driver.page_source

# Close the Selenium webdriver
driver.quit()

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# %%
# Find the image tags and extract the src attribute
image_tags = soup.find_all('img')
image_addresses = [img['src'] for img in image_tags]

# %%
print(image_addresses)
# Out:
# ['https://www.shutterstock.com/shutterstock/photos/2221121763/display_1500/stock-photo-professional-builder-in-vr-helmet-standing-in-front-of-construction-site-and-using-virtual-and-2221121763.jpg', 'https://www.shutterstock.com/shutterstock/photos/2236433321/display_1500/stock-photo-future-building-construction-engineering-project-devotion-with-double-exposure-graphic-design-2236433321.jpg', 'https://www.shutterstock.com/shutterstock/photos/1847969575/display_1500/stock-photo-factory-worker-in-hard-hat-and-safety-vest-talks-on-two-way-radio-man-with-clipping-path-on-white-1847969575.jpg', 'https://www.shutterstock.com/shutterstock/photos/2141805419/display_1500/stock-photo-happy-african-builder-workman-standing-pleased-crossing-hands-posing-on-gray-studio-background-2141805419.jpg', 'https://www.shutterstock.com/shutterstock/photos/1737846935/display_1500/stock-photo-safety-body-construction-working-at-height-equipment-fall-arrestor-device-for-worker-with-hooks-1737846935.jpg', 'htt
# ...

# %%
dossier='its_scraping_time/'
avec_casque='oui_casque/'
sans_casque='non_casque/'


chemin=f'{dossier}{avec_casque}'

# %%
import urllib.request
y=500
for i, url in enumerate(image_set):
    file_name = f'{chemin}image{i+y+1}.jpg'
    urllib.request.urlretrieve(url, file_name)
    print(f'Downloaded {file_name}')
# Out:
# Downloaded its_scraping_time/oui_casque/image501.jpg
# Downloaded its_scraping_time/oui_casque/image502.jpg
# Downloaded its_scraping_time/oui_casque/image503.jpg
# Downloaded its_scraping_time/oui_casque/image504.jpg
# Downloaded its_scraping_time/oui_casque/image505.jpg
# Downloaded its_scraping_time/oui_casque/image506.jpg
# Downloaded its_scraping_time/oui_casque/image507.jpg
# Downloaded its_scraping_time/oui_casque/image508.jpg
# Downloaded its_scraping_time/oui_casque/image509.jpg
# Downloaded its_scraping_time/oui_casque/image510.jpg
# Downloaded its_scraping_time/oui_casque/image511.jpg
# Downloaded its_scraping_time/oui_casque/image512.jpg
# Downloaded its_scraping_time/oui_casque/image513.jpg
# Downloaded its_scraping_time/oui_casque/image514.jpg
# Downloaded its_scraping_time/oui_casque/image515.jpg
# Downloaded its_scraping_time/oui_casque/image516.jpg
# Downloaded its_scraping_time/oui_casque/image517.jpg
# Downloaded its_scraping_time/oui_casque/image518.jpg
# ...

# %%
#del(image_set[0])

# %%
image_set
# Out:
# ['https://www.shutterstock.com/shutterstock/photos/2221121763/display_1500/stock-photo-professional-builder-in-vr-helmet-standing-in-front-of-construction-site-and-using-virtual-and-2221121763.jpg',
#  'https://www.shutterstock.com/shutterstock/photos/2236433321/display_1500/stock-photo-future-building-construction-engineering-project-devotion-with-double-exposure-graphic-design-2236433321.jpg',
#  'https://www.shutterstock.com/shutterstock/photos/1847969575/display_1500/stock-photo-factory-worker-in-hard-hat-and-safety-vest-talks-on-two-way-radio-man-with-clipping-path-on-white-1847969575.jpg',
#  'https://www.shutterstock.com/shutterstock/photos/2141805419/display_1500/stock-photo-happy-african-builder-workman-standing-pleased-crossing-hands-posing-on-gray-studio-background-2141805419.jpg',
# ...
